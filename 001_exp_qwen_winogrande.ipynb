# %% [markdown]
# ## 🔬 Experiment 1: Reasoning Transfer via Precomputed Context
#
# ### 🎯 Core Hypothesis
# > *Reasoning steps (tokens) computed for a single, complex sample can be extracted, "frozen," and injected as precomputed context into subsequent queries. This transfer will improve the LLM's performance (accuracy/consistency) on new samples of the same domain compared to standard zero-shot generation.*
#
# ### ⚙️ Pipeline Architecture
# 0. **Reasoning Token Extraction:** Prompt Qwen 3.5:4b with a random sample question from the data set "", strip the final answer, and store *only* the reasoning tokens as a static string.
# 1. **Baseline:** For each sample of the data-set, prompt Qwen 3.5:4b with the sample, turn-off thinking and force the model to only awnser the question.
# 2. **Injection:** For each sample of the data-set, prompt Qwen 3.5:4b with the sample, turn-off thinking, add the extracted reasoning tokens and force the model to only awnser the question.
#
# ### 📊 Evaluation Metrics
# * **Accuracy:** Does the injected context increase the rate of correctly solved subsequent samples?
# * **Efficiency:** Does the provision of precomputed reasoning reduce the total generation time or token count for subsequent queries?

# %%
import time
import json
import os
import subprocess
import random
from datetime import datetime
from langchain_ollama import ChatOllama
from langchain_core.messages import HumanMessage, SystemMessage
from datasets import load_dataset

# %%
# Dynamic IP retrieval for Windows host
windows_ip = subprocess.check_output("ip route list default | awk '{print $3}'", shell=True).decode('utf-8').strip()

# Set llm model parameters (qwen3.5:4b)
llm_model = ChatOllama(
    model="qwen3.5:4b", 
    base_url=f"http://{windows_ip}:11434", 
    presence_penalty=1.5,
    temperature=1,
    top_p=0.95,
    top_k=20,
)

# %%
# Load WinoGrande dataset and select a subset for the experiment
dataset = load_dataset("allenai/winogrande", "winogrande_s")
experiment0_samples = dataset['validation'].select(range(500))
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
import json
import random
from datetime import datetime
from langchain_core.messages import SystemMessage, HumanMessage

# 1. Get a random anchor sample for extraction
anchor_index = random.randint(0, len(experiment0_samples)-1)
anchor_sample = experiment0_samples[anchor_index]
anchor_question = f"Question: {anchor_sample['sentence']}, Options: {anchor_sample['option1']} or {anchor_sample['option2']}."

print(f"Anchor Sample selected (Index {anchor_index}): {anchor_question}")

# 2. Define prompt structures and Placebo Text
system_instruction = "You are a meticulous assistant. Fill in the blank (_) in the sentence with the logically correct option."

baseline_prompt_structure = "Question: {sentence} Options: {option1} or {option2}. Please provide only the correct option as the answer."

# We use the same structure for both Injected Reasoning and the Control Placebo
injected_prompt_structure = "Question: {sentence} Options: {option1} or {option2}. Please provide only the correct option as the answer. \n\n Here is some information to help you: {injection_content}. \n\n Let me repeat the question: {sentence} Choose one of the two options: {option1} or {option2}. Only answer with the correct option for the question, and not with the provided information."

control_prompt_structure = "Question: {sentence} Options: {option1} or {option2}. Please provide only the correct option as the answer. \n\n Here is some information to help you: {control_content}. \n\n Let me repeat the question: {sentence} Choose one of the two options: {option1} or {option2}. Only answer with the correct option for the question, and not with the provided information."


# Placebo Text (Wikipedia excerpt, unrelated to WinoGrande commonsense)
control_text = "Happiness Is a Warm Gun is a feature film by the Swiss director Thomas Imbach, who stages the life and death story of the lovers Petra Kelly and Gert Bastian. Between documentary-like scenes and fictional acting, as well as archive material, the narrative of a love story is created, rolled up from its end. Happiness Is a Warm Gun premiered at the International Locarno Film Festival in August 2001.[1] The film won the Zurich Film Prize 2001[2] and was nominated for the Swiss Film Prize for best feature film and best leading actress. \n\nPLOT: Happiness Is a Warm Gun is about the murder of the green pacifist Petra Kelly, who is shot in her sleep by her life partner Gert Bastian, ex-Bundeswehr-General, before he kills himself. The film begins where the lives of the real characters end. Petra and Gert find themselves in the transit area of a modern airport and settle down in this artificial in-between world, trying to pick up the thread of the past - their political activity - while in their conversations what happened is fragmentary. \n\n Background: "After leaving the Bundestag, Kelly lived with her partner Gert Bastian in seclusion in their house in the Tannenbusch district of Bonn. She was seriously ill and suffered from fear of threats (after having received threatening letters). She was on the police's list of endangered personalities, but refused personal protection. According to the police report, Kelly was killed in her sleep by Bastian with his Deringer-type pistol under circumstances that are not completely clear, and Bastian is said to have put an end to his life afterwards, whereby according to a report in Der Spiegel magazine, the gun was aimed from above at a spot just above the forehead. The bodies were found on October 19, 1992 - several weeks after the crime. The exact date could therefore no longer be determined with certainty; the time of death is assumed to be the night of October 1, 1992."

# 3. Preprocessing: Generate LLM reasoning for the anchor
preprocessed_reasoning_tokens = llm_model.invoke([
    SystemMessage(content=system_instruction),
    HumanMessage(content=f"{anchor_question} Please provide only the correct option as the answer.")
], reasoning=True).additional_kwargs.get("reasoning_content")

print("\nPreprocessed Reasoning Tokens:", preprocessed_reasoning_tokens, "\n")

# 4. Initialize new log structure (now tracking 3 states)
experiment_log = {
    "metadata": {
        "dataset": "WinoGrande",
        "sample_size": len(experiment0_samples),
        "anchor_sample_index": anchor_index,
        "anchor_question": anchor_question,
        "injected_reasoning_tokens": preprocessed_reasoning_tokens,
        "control_placebo_text": control_text,
        "system_prompt": system_instruction,
        "baseline_prompt_structure": baseline_prompt_structure,
        "injected_prompt_structure": injected_prompt_structure,
        "control_prompt_structure": injected_prompt_structure
    },
    "results": {}
}

# 5. The main loop
for index, sample in enumerate(experiment0_samples):
    sample_id = f"sample_{index:03d}"
    correct_solution = sample[f"option{sample['answer']}"]
    
    # Cleanly fill prompts via .format() using the template variables
    baseline_human_prompt = baseline_prompt_structure.format(
        sentence=sample['sentence'],
        option1=sample['option1'],
        option2=sample['option2']
    )
    
    # Fill with actual Reasoning
    reasoning_human_prompt = injected_prompt_structure.format(
        injection_content=preprocessed_reasoning_tokens,
        sentence=sample['sentence'],
        option1=sample['option1'],
        option2=sample['option2']
    )

    # Fill with Placebo Wikipedia Text
    control_human_prompt = control_prompt_structure.format(
        control_content=control_text,
        sentence=sample['sentence'],
        option1=sample['option1'],
        option2=sample['option2']
    )

    # Run 1: Baseline
    response_baseline = llm_model.invoke([
        SystemMessage(content=system_instruction),
        HumanMessage(content=baseline_human_prompt)
    ], reasoning=False)
    baseline_answer = response_baseline.content.strip()

    # Run 2: Reasoning Injection
    response_reasoning = llm_model.invoke([
        SystemMessage(content=system_instruction),
        HumanMessage(content=reasoning_human_prompt)
    ], reasoning=False)
    reasoning_answer = response_reasoning.content.strip()

    # Run 3: Placebo Control Injection
    response_control = llm_model.invoke([
        SystemMessage(content=system_instruction),
        HumanMessage(content=control_human_prompt)
    ], reasoning=False)
    control_answer = response_control.content.strip()

    print(f"{sample_id} - Sol: {correct_solution} | Base: {baseline_answer} | Reason: {reasoning_answer} | Placebo: {control_answer}")
    
    # Write results to the results dictionary
    experiment_log["results"][sample_id] = {
        "solution": correct_solution,
        "llm_baseline": baseline_answer,
        "llm_preprocessedReasoning": reasoning_answer,
        "llm_controlPlacebo": control_answer
    }

# 6. Save results
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
log_filename = f"logs/qwen_experiment_log_{timestamp}.json"

with open(log_filename, "w", encoding="utf-8") as f:
    json.dump(experiment_log, f, indent=4, ensure_ascii=False)

print(f"\n✅ Experiment successfully saved in {log_filename}!")
# Out:
# Anchor Sample selected (Index 47): Question: It was easy for Angela to become a vegetarian although Kayla couldn't do it. _ really missed the taste of chicken., Options: Angela or Kayla.
#
# Preprocessed Reasoning Tokens: Thinking Process:
#
# 1.  **Analyze the Request:**
#     *   Input: A sentence with a blank ("_ really missed the taste of chicken.") and two options (Angela or Kayla).
#     *   Context: "It was easy for Angela to become a vegetarian although Kayla couldn't do it."
#     *   Task: Fill in the blank with the logically correct option.
#     *   Constraint: Provide *only* the correct option as the answer.
#
# 2.  **Analyze the Sentence Context:**
#     *   Clause 1: "It was easy for Angela to become a vegetarian..." (Angela *can* become/has become a vegetarian).
#     *   Clause 2: "...although Kayla couldn't do it." (Kayla *cannot* become a vegetarian).
#     *   Implied meaning: Angela gave up meat (became vegetarian), while Kayla did not give up meat (didn't do it).
#     *   Clause 3 (The blank): "____ really missed the taste of chicken."
#     *   Logic: Who misses chicken? The person who eats chicken.
#     *   Angela is a vegetarian (no chicken). Therefore, she would not miss chicken or would not really miss it based on the context of her dietary change being "easy" (often implying no strong emotional struggle).
#     *   Kayla couldn't do it (didn't become vegetarian). Therefore, Kayla still eats meat/chicken.
#     *   Consequently, Kayla is the one who would "miss the taste of chicken."
#
# 3.  **Evaluate Options:**
#     *   Option 1: Angela (Vegetarian, no chicken). Unlikely to miss chicken in the context of the first part.
#     *   Option 2: Kayla (Not vegetarian, eats chicken). Logical to say she missed the taste.
#
# 4.  **Formulate Output:**
#     *   Constraint: "Please provide only the correct option as the answer."
#     *   Draft: Kayla.
#
# 5.  **Final Check:**
#     *   Does "Kayla really missed the taste of chicken" make sense given the premise? Yes.
#     *   Does "Angela really missed the taste of chicken" make sense? No, she's a vegetarian.
#     *   Is the output format correct? Yes, just the name.
#
# 6.  **Final Decision:** Kayla.cw
#
# sample_000 - Solution: Maria | Baseline: Sarah vs. Injected: Sarah
# sample_001 - Solution: Sarah | Baseline: Sarah vs. Injected: Sarah
# sample_002 - Solution: bed | Baseline: bed vs. Injected: blanket
# sample_003 - Solution: eggplant | Baseline: eggplant vs. Injected: eggplant
# sample_004 - Solution: Jeffrey | Baseline: Hunter vs. Injected: Hunter
# sample_005 - Solution: Sarah | Baseline: Sarah vs. Injected: Sarah
# sample_006 - Solution: home | Baseline: home vs. Injected: home
# sample_007 - Solution: house | Baseline: house vs. Injected: house
# sample_008 - Solution: Jennifer | Baseline: Natalie vs. Injected: Jennifer
# sample_009 - Solution: bakery | Baseline: bank vs. Injected: bank
# sample_010 - Solution: bank | Baseline: bakery vs. Injected: bakery
# sample_011 - Solution: class | Baseline: class vs. Injected: class
# sample_012 - Solution: story | Baseline: story vs. Injected: story
# sample_013 - Solution: cafe | Baseline: cafe vs. Injected: cafe
# sample_014 - Solution: library | Baseline: library vs. Injected: library
# sample_015 - Solution: Lindsey | Baseline: Lindsey vs. Injected: Lindsey
# sample_016 - Solution: Leslie | Baseline: Michael vs. Injected: Leslie
# sample_017 - Solution: Michael | Baseline: Leslie vs. Injected: Leslie
# sample_018 - Solution: Leslie | Baseline: Neil vs. Injected: Neil
# sample_019 - Solution: Adam | Baseline: Adam vs. Injected: Adam
# sample_020 - Solution: frosting | Baseline: frosting vs. Injected: frosting
# sample_021 - Solution: Brett | Baseline: Brett vs. Injected: Brett
# sample_022 - Solution: Amy | Baseline: Amy vs. Injected: Amy
# sample_023 - Solution: work | Baseline: strength vs. Injected: strength
# sample_024 - Solution: strength | Baseline: work vs. Injected: strength
# sample_025 - Solution: Rachel | Baseline: Rachel vs. Injected: Rachel
# sample_026 - Solution: Leslie | Baseline: Leslie vs. Injected: Leslie
# sample_027 - Solution: portions | Baseline: portions vs. Injected: sizes
# sample_028 - Solution: Craig | Baseline: Craig vs. Injected: Craig
# sample_029 - Solution: Christine | Baseline: Jessica vs. Injected: Jessica
# sample_030 - Solution: desks | Baseline: desks vs. Injected: desks
# sample_031 - Solution: Mary | Baseline: Mary vs. Injected: Mary
# sample_032 - Solution: Rachel | Baseline: Rachel vs. Injected: Rachel
# sample_033 - Solution: Leslie | Baseline: Kyle vs. Injected: Kyle
# sample_034 - Solution: Betty | Baseline: Jessica vs. Injected: Betty
# sample_035 - Solution: floor | Baseline: floor vs. Injected: floor
# sample_036 - Solution: Eric | Baseline: Eric vs. Injected: Joel
# sample_037 - Solution: Tanya | Baseline: Tanya vs. Injected: Emily
# sample_038 - Solution: Lindsey | Baseline: Angela vs. Injected: Angela
# sample_039 - Solution: Joseph | Baseline: Joseph vs. Injected: Joseph
# sample_040 - Solution: Brian | Baseline: Brian vs. Injected: Brett
# sample_041 - Solution: letters | Baseline: eyes vs. Injected: letters
# sample_042 - Solution: hat | Baseline: hat vs. Injected: dress
# sample_043 - Solution: dress | Baseline: hat vs. Injected: hat
# sample_044 - Solution: Felicia | Baseline: Felicia vs. Injected: Felicia
# sample_045 - Solution: Craig | Baseline: Craig vs. Injected: William
# sample_046 - Solution: William | Baseline: William vs. Injected: William
# sample_047 - Solution: Kayla | Baseline: Kayla vs. Injected: Kayla
# sample_048 - Solution: Logan | Baseline: Logan vs. Injected: Hunter
# sample_049 - Solution: Tanya | Baseline: Tanya vs. Injected: Tanya
# sample_050 - Solution: brush | Baseline: The crack vs. Injected: brush
# sample_051 - Solution: crack | Baseline: brush vs. Injected: crack
# sample_052 - Solution: newspaper | Baseline: newspaper vs. Injected: newspaper
# sample_053 - Solution: Natalie | Baseline: Natalie vs. Injected: Jennifer
# sample_054 - Solution: Jennifer | Baseline: Natalie vs. Injected: Jennifer
# sample_055 - Solution: Ryan | Baseline: Ryan vs. Injected: Matthew
# sample_056 - Solution: distance | Baseline: food vs. Injected: distance
# sample_057 - Solution: Brian | Baseline: Brian vs. Injected: Brian
# sample_058 - Solution: Nick | Baseline: Dennis vs. Injected: Dennis
# sample_059 - Solution: Monica | Baseline: Monica vs. Injected: Monica
# sample_060 - Solution: war | Baseline: war vs. Injected: war
# sample_061 - Solution: Erin | Baseline: Erin vs. Injected: Erin
# sample_062 - Solution: table | Baseline: table vs. Injected: phone
# sample_063 - Solution: phone | Baseline: phone vs. Injected: phone
# sample_064 - Solution: air | Baseline: air vs. Injected: air
# sample_065 - Solution: rags | Baseline: nozzles vs. Injected: rags
# sample_066 - Solution: ear | Baseline: piercing vs. Injected: piercing
# sample_067 - Solution: piercing | Baseline: piercing vs. Injected: piercing
# sample_068 - Solution: Felicia | Baseline: Felicia vs. Injected: Laura
# sample_069 - Solution: Carrie | Baseline: Carrie vs. Injected: Carrie
# sample_070 - Solution: shirt | Baseline: shirt vs. Injected: shirt
# sample_071 - Solution: paint | Baseline: paint vs. Injected: paint
# sample_072 - Solution: glow sticks | Baseline: glow sticks vs. Injected: glow sticks
# sample_073 - Solution: Joseph | Baseline: Joel vs. Injected: Joseph
# sample_074 - Solution: Joel | Baseline: Joseph vs. Injected: Joseph
# sample_075 - Solution: shirt | Baseline: shirt vs. Injected: shirt
# sample_076 - Solution: Patricia | Baseline: Patricia vs. Injected: Mary
# sample_077 - Solution: Mary | Baseline: Mary vs. Injected: Mary
# sample_078 - Solution: house | Baseline: playground vs. Injected: playground
# sample_079 - Solution: Aaron | Baseline: Dennis vs. Injected: Dennis
# sample_080 - Solution: Dennis | Baseline: Dennis vs. Injected: Dennis
# sample_081 - Solution: day | Baseline: night vs. Injected: day
# sample_082 - Solution: Joel | Baseline: Joel vs. Injected: Joel
# sample_083 - Solution: living room | Baseline: living room vs. Injected: living room
# sample_084 - Solution: bedroom | Baseline: bedroom vs. Injected: bedroom
# sample_085 - Solution: Amy | Baseline: Samantha vs. Injected: Samantha
# sample_086 - Solution: Jessica | Baseline: Jessica vs. Injected: Megan
# sample_087 - Solution: Megan | Baseline: Megan vs. Injected: Jessica
# sample_088 - Solution: Natalie | Baseline: Natalie vs. Injected: Natalie
# sample_089 - Solution: Amy | Baseline: Amy vs. Injected: Amy
# sample_090 - Solution: woven necklace | Baseline: ball vs. Injected: ball
# sample_091 - Solution: Carrie | Baseline: Carrie vs. Injected: Carrie
# sample_092 - Solution: doors | Baseline: desks vs. Injected: desks
# sample_093 - Solution: desks | Baseline: desks vs. Injected: doors
# sample_094 - Solution: bark | Baseline: bark vs. Injected: stone
# sample_095 - Solution: stone | Baseline: stone vs. Injected: stone
# sample_096 - Solution: body | Baseline: body vs. Injected: body
# sample_097 - Solution: sheet | Baseline: The sheet vs. Injected: sheet
# sample_098 - Solution: space | Baseline: space vs. Injected: sheet
# sample_099 - Solution: couch | Baseline: couch vs. Injected: couch
# sample_100 - Solution: Craig | Baseline: Craig vs. Injected: Craig
# sample_101 - Solution: Steven | Baseline: Craig vs. Injected: Craig
# sample_102 - Solution: dinner | Baseline: dinner vs. Injected: dinner
# sample_103 - Solution: Angela | Baseline: Rebecca vs. Injected: Rebecca
# sample_104 - Solution: Rebecca | Baseline: Rebecca vs. Injected: Rebecca
# sample_105 - Solution: cash | Baseline: cash vs. Injected: cash
# sample_106 - Solution: Christine | Baseline: Christine vs. Injected: Kayla
# sample_107 - Solution: pie | Baseline: pie vs. Injected: pie
# sample_108 - Solution: surgery | Baseline: diet vs. Injected: surgery
# sample_109 - Solution: Rachel | Baseline: Rachel vs. Injected: Rachel
# sample_110 - Solution: Megan | Baseline: Rachel vs. Injected: Megan
# sample_111 - Solution: Kayla | Baseline: Kayla vs. Injected: Kayla
# sample_112 - Solution: Randy | Baseline: Randy vs. Injected: Randy
# sample_113 - Solution: Dennis | Baseline: Jeffrey vs. Injected: Jeffrey
# sample_114 - Solution: Elena | Baseline: Elena vs. Injected: Elena
# sample_115 - Solution: Betty | Baseline: Betty vs. Injected: Betty
# sample_116 - Solution: sofa | Baseline: offer vs. Injected: sofa
# sample_117 - Solution: books | Baseline: books vs. Injected: books
# sample_118 - Solution: leaves | Baseline: books vs. Injected: books
# sample_119 - Solution: auditorium | Baseline: park vs. Injected: park
# sample_120 - Solution: park | Baseline: auditorium vs. Injected: park
# sample_121 - Solution: Steven | Baseline: Robert vs. Injected: Robert
# sample_122 - Solution: Robert | Baseline: Robert vs. Injected: Robert
# sample_123 - Solution: apple | Baseline: apple vs. Injected: apple
# sample_124 - Solution: braces | Baseline: glasses vs. Injected: glasses
# sample_125 - Solution: glasses | Baseline: glasses vs. Injected: glasses
# sample_126 - Solution: Ian | Baseline: Randy vs. Injected: Randy
# sample_127 - Solution: Joseph | Baseline: Joseph vs. Injected: Joseph
# sample_128 - Solution: Adam | Baseline: Joseph vs. Injected: Joseph
# sample_129 - Solution: factory | Baseline: plant vs. Injected: factory
# sample_130 - Solution: William | Baseline: William vs. Injected: William
# sample_131 - Solution: Rachel | Baseline: Amy vs. Injected: Amy
# sample_132 - Solution: rattle | Baseline: bottle vs. Injected: bottle
# sample_133 - Solution: Samantha | Baseline: Samantha vs. Injected: Rebecca
# sample_134 - Solution: Michael | Baseline: Aaron vs. Injected: Michael
# sample_135 - Solution: Jennifer | Baseline: Jennifer vs. Injected: Jennifer
# sample_136 - Solution: room | Baseline: clock vs. Injected: room
# sample_137 - Solution: Donald | Baseline: Donald vs. Injected: Donald
# sample_138 - Solution: Logan | Baseline: Donald vs. Injected: Donald
# sample_139 - Solution: Ryan | Baseline: Ryan vs. Injected: Kyle
# sample_140 - Solution: house | Baseline: wind vs. Injected: wind
# sample_141 - Solution: Samantha | Baseline: Samantha vs. Injected: Betty
# sample_142 - Solution: Rebecca | Baseline: Rebecca vs. Injected: Maria
# sample_143 - Solution: jewelry | Baseline: card vs. Injected: card
# sample_144 - Solution: Laura | Baseline: Monica vs. Injected: Monica
# sample_145 - Solution: Monica | Baseline: Monica vs. Injected: Laura
# sample_146 - Solution: internet | Baseline: internet vs. Injected: cable
# sample_147 - Solution: cable | Baseline: cable vs. Injected: cable
# sample_148 - Solution: Mary | Baseline: Mary vs. Injected: Jessica
# sample_149 - Solution: Matthew | Baseline: Matthew vs. Injected: Matthew
# sample_150 - Solution: Megan | Baseline: Monica vs. Injected: Monica
# sample_151 - Solution: eyelashes | Baseline: eyebrows vs. Injected: eyelashes
# sample_152 - Solution: Samuel | Baseline: Brett vs. Injected: Brett
# sample_153 - Solution: Kayla | Baseline: Kayla vs. Injected: Kayla
# sample_154 - Solution: watch | Baseline: watch vs. Injected: watch
# sample_155 - Solution: Michael | Baseline: Michael vs. Injected: Michael
# sample_156 - Solution: house | Baseline: house vs. Injected: office
# sample_157 - Solution: Patricia | Baseline: Patricia vs. Injected: Felicia
# sample_158 - Solution: Felicia | Baseline: Patricia vs. Injected: Felicia
# sample_159 - Solution: Elena | Baseline: Elena vs. Injected: Elena
# sample_160 - Solution: Kyle | Baseline: Kyle vs. Injected: Kyle
# sample_161 - Solution: William | Baseline: Kyle vs. Injected: William
# sample_162 - Solution: canoe | Baseline: canoe vs. Injected: raft
# sample_163 - Solution: Jessica | Baseline: Jessica vs. Injected: Jessica
# sample_164 - Solution: gun | Baseline: cloth vs. Injected: gun
# sample_165 - Solution: cloth | Baseline: cloth vs. Injected: cloth
# sample_166 - Solution: hammer | Baseline: hammer vs. Injected: hammer
# sample_167 - Solution: screwdriver | Baseline: hammer vs. Injected: hammer
# sample_168 - Solution: winter | Baseline: winter vs. Injected: winter
# sample_169 - Solution: Ian | Baseline: Ian vs. Injected: Ian
# sample_170 - Solution: Vase | Baseline: Vase vs. Injected: Urn
# sample_171 - Solution: Urn | Baseline: urn vs. Injected: Urn
# sample_172 - Solution: school | Baseline: school vs. Injected: school
# sample_173 - Solution: Jessica | Baseline: Samantha vs. Injected: Samantha
# sample_174 - Solution: car | Baseline: car vs. Injected: car
# sample_175 - Solution: city | Baseline: village vs. Injected: city
# sample_176 - Solution: Rachel | Baseline: Patricia vs. Injected: Rachel
# sample_177 - Solution: Patricia | Baseline: Patricia vs. Injected: Patricia
# sample_178 - Solution: Neil | Baseline: Samuel vs. Injected: Neil
# sample_179 - Solution: color | Baseline: color vs. Injected: color
# sample_180 - Solution: garage | Baseline: drums vs. Injected: garage
# sample_181 - Solution: Rebecca | Baseline: Rebecca vs. Injected: Rebecca
# sample_182 - Solution: water | Baseline: water vs. Injected: water
# sample_183 - Solution: sand | Baseline: sand vs. Injected: sand
# sample_184 - Solution: warts | Baseline: warts vs. Injected: warts
# sample_185 - Solution: blanket | Baseline: sheet vs. Injected: sheet
# sample_186 - Solution: PVC | Baseline: PVC vs. Injected: PVC
# sample_187 - Solution: Rebecca | Baseline: Rebecca vs. Injected: Rebecca
# sample_188 - Solution: Adam | Baseline: Adam vs. Injected: Adam
# sample_189 - Solution: puncture | Baseline: puncture vs. Injected: puncture
# sample_190 - Solution: Emily | Baseline: Emily vs. Injected: Emily
# sample_191 - Solution: leather | Baseline: silk vs. Injected: silk
# sample_192 - Solution: Lawrence | Baseline: Lawrence vs. Injected: Lawrence
# sample_193 - Solution: Nick | Baseline: Lawrence vs. Injected: Nick
# sample_194 - Solution: camera | Baseline: tray vs. Injected: camera
# sample_195 - Solution: Brett | Baseline: Brett vs. Injected: Nelson
# sample_196 - Solution: Nelson | Baseline: Nelson vs. Injected: Brett
# sample_197 - Solution: Adam | Baseline: Adam vs. Injected: Adam
# sample_198 - Solution: Craig | Baseline: Eric vs. Injected: Eric
# sample_199 - Solution: Eric | Baseline: Eric vs. Injected: Eric
# sample_200 - Solution: Victoria | Baseline: Sarah vs. Injected: Sarah
# sample_201 - Solution: Sarah | Baseline: Sarah vs. Injected: Sarah
# sample_202 - Solution: Randy | Baseline: Randy vs. Injected: Randy
# sample_203 - Solution: Cynthia | Baseline: Laura vs. Injected: Laura
# sample_204 - Solution: Laura | Baseline: Laura vs. Injected: Laura
# sample_205 - Solution: tables | Baseline: chairs vs. Injected: tables
# sample_206 - Solution: chairs | Baseline: chairs vs. Injected: chairs
# sample_207 - Solution: Steven | Baseline: Steven vs. Injected: Steven
# sample_208 - Solution: shoe | Baseline: nail vs. Injected: shoe
# sample_209 - Solution: Jason | Baseline: Jason vs. Injected: Jason
# sample_210 - Solution: Lawrence | Baseline: Jason vs. Injected: Jason
# sample_211 - Solution: rock | Baseline: fishing line vs. Injected: fishing line
# sample_212 - Solution: fruits | Baseline: vegetables vs. Injected: fruits
# sample_213 - Solution: Elena | Baseline: Victoria vs. Injected: Victoria
# sample_214 - Solution: Victoria | Baseline: Victoria vs. Injected: Victoria
# sample_215 - Solution: hookup | Baseline: past due vs. Injected: hookup
# sample_216 - Solution: Cynthia | Baseline: Amy vs. Injected: Amy
# sample_217 - Solution: Ian | Baseline: Ian vs. Injected: Ian
# sample_218 - Solution: tomatoes | Baseline: tomatoes vs. Injected: tomatoes
# sample_219 - Solution: Joseph | Baseline: Joseph vs. Injected: Joseph
# sample_220 - Solution: store | Baseline: store vs. Injected: store
# sample_221 - Solution: garden | Baseline: garden vs. Injected: store
# sample_222 - Solution: Samantha | Baseline: Sarah vs. Injected: Sarah
# sample_223 - Solution: Brett | Baseline: Justin vs. Injected: Brett
# sample_224 - Solution: Justin | Baseline: Justin vs. Injected: Justin
# sample_225 - Solution: William | Baseline: Adam vs. Injected: Adam
# sample_226 - Solution: garage | Baseline: garage vs. Injected: garage
# sample_227 - Solution: Adam | Baseline: Kevin vs. Injected: Kevin
# sample_228 - Solution: Victoria | Baseline: Victoria vs. Injected: Victoria
# sample_229 - Solution: Carrie | Baseline: Victoria vs. Injected: Victoria
# sample_230 - Solution: gym | Baseline: gym vs. Injected: bar
# sample_231 - Solution: bar | Baseline: gym vs. Injected: gym
# sample_232 - Solution: Samuel | Baseline: Randy vs. Injected: Samuel
# sample_233 - Solution: Elena | Baseline: Amy vs. Injected: Elena
# sample_234 - Solution: Amy | Baseline: Amy vs. Injected: Amy
# sample_235 - Solution: Ryan | Baseline: Ryan vs. Injected: Ryan
# sample_236 - Solution: Natalie | Baseline: Natalie vs. Injected: Jennifer
# sample_237 - Solution: Victoria | Baseline: Emily vs. Injected: Emily
# sample_238 - Solution: Emily | Baseline: Emily vs. Injected: Emily
# sample_239 - Solution: Mary | Baseline: Rachel vs. Injected: Rachel
# sample_240 - Solution: Jason | Baseline: Jason vs. Injected: Jason
# sample_241 - Solution: Natalie | Baseline: Natalie vs. Injected: Natalie
# sample_242 - Solution: court | Baseline: company vs. Injected: court
# sample_243 - Solution: Tablet | Baseline: Tablet vs. Injected: Tablet
# sample_244 - Solution: Phone | Baseline: Tablet vs. Injected: Phone
# sample_245 - Solution: Logan | Baseline: Neil vs. Injected: Neil
# sample_246 - Solution: Carrie | Baseline: Carrie vs. Injected: Carrie
# sample_247 - Solution: region | Baseline: region vs. Injected: people
# sample_248 - Solution: Samantha | Baseline: Jessica vs. Injected: Jessica
# sample_249 - Solution: Donald | Baseline: Jason vs. Injected: Jason
# sample_250 - Solution: Jason | Baseline: Donald vs. Injected: Jason
# sample_251 - Solution: Carrie | Baseline: Carrie vs. Injected: Emily
# sample_252 - Solution: Emily | Baseline: Emily vs. Injected: Emily
# sample_253 - Solution: Ian | Baseline: Craig vs. Injected: Craig
# sample_254 - Solution: Craig | Baseline: Craig vs. Injected: Ian
# sample_255 - Solution: wool | Baseline: wool vs. Injected: wool
# sample_256 - Solution: cotton | Baseline: wool vs. Injected: wool
# sample_257 - Solution: contacts | Baseline: glasses vs. Injected: glasses
# sample_258 - Solution: paper | Baseline: paper vs. Injected: exam
# sample_259 - Solution: diner | Baseline: supermarket vs. Injected: supermarket
# sample_260 - Solution: pencil | Baseline: pencil vs. Injected: pencil
# sample_261 - Solution: William | Baseline: Eric vs. Injected: William
# sample_262 - Solution: urn | Baseline: urn vs. Injected: urn
# sample_263 - Solution: Jennifer | Baseline: Jennifer vs. Injected: Sarah
# sample_264 - Solution: Sarah | Baseline: Sarah vs. Injected: Sarah
# sample_265 - Solution: Kevin | Baseline: Kevin vs. Injected: Kevin
# sample_266 - Solution: Neil | Baseline: Kevin vs. Injected: Neil
# sample_267 - Solution: house | Baseline: house vs. Injected: library
# sample_268 - Solution: library | Baseline: house vs. Injected: house
# sample_269 - Solution: slide | Baseline: slide vs. Injected: slide
# sample_270 - Solution: Ryan | Baseline: Ryan vs. Injected: Michael
# sample_271 - Solution: shop | Baseline: shop vs. Injected: garage
# sample_272 - Solution: pocket watch | Baseline: pocket watch vs. Injected: pocket watch
# sample_273 - Solution: sci-fi movies | Baseline: sci-fi movies vs. Injected: sci-fi movies
# sample_274 - Solution: Christine | Baseline: Laura vs. Injected: Laura
# sample_275 - Solution: bikini | Baseline: top vs. Injected: top
# sample_276 - Solution: top | Baseline: top vs. Injected: top
# sample_277 - Solution: Elena | Baseline: Victoria vs. Injected: Elena
# sample_278 - Solution: Angela | Baseline: Mary vs. Injected: Mary
# sample_279 - Solution: Betty | Baseline: Betty vs. Injected: Kayla
# sample_280 - Solution: Eric | Baseline: Eric vs. Injected: Eric
# sample_281 - Solution: mango | Baseline: cup vs. Injected: cup
# sample_282 - Solution: pie | Baseline: cookies vs. Injected: pie
# sample_283 - Solution: Brian | Baseline: Brian vs. Injected: Nick
# sample_284 - Solution: clock | Baseline: conversation vs. Injected: clock
# sample_285 - Solution: Laura | Baseline: Amy vs. Injected: Amy
# sample_286 - Solution: Nelson | Baseline: Ryan vs. Injected: Ryan
# sample_287 - Solution: Kenneth | Baseline: Kenneth vs. Injected: Kenneth
# sample_288 - Solution: Katrina | Baseline: Cynthia vs. Injected: Katrina
# sample_289 - Solution: pen | Baseline: pen vs. Injected: pen
# sample_290 - Solution: Matthew | Baseline: Logan vs. Injected: Matthew
# sample_291 - Solution: Patricia | Baseline: Victoria vs. Injected: Patricia
# sample_292 - Solution: Victoria | Baseline: Victoria vs. Injected: Victoria
# sample_293 - Solution: dolls | Baseline: dolls vs. Injected: dolls
# sample_294 - Solution: bike | Baseline: bike vs. Injected: car
# sample_295 - Solution: car | Baseline: car vs. Injected: car
# sample_296 - Solution: Jeffrey | Baseline: Michael vs. Injected: Jeffrey
# sample_297 - Solution: Patricia | Baseline: Carrie vs. Injected: Carrie
# sample_298 - Solution: Carrie | Baseline: Carrie vs. Injected: Carrie
# sample_299 - Solution: Leslie | Baseline: Eric vs. Injected: Leslie
# sample_300 - Solution: Jessica | Baseline: Rachel vs. Injected: Jessica
# sample_301 - Solution: Erin | Baseline: Maria vs. Injected: Erin
# sample_302 - Solution: Kenneth | Baseline: Ian vs. Injected: Ian
# sample_303 - Solution: Christine | Baseline: Tanya vs. Injected: Tanya
# sample_304 - Solution: Derrick | Baseline: Steven vs. Injected: Steven
# sample_305 - Solution: Steven | Baseline: Steven vs. Injected: Steven
# sample_306 - Solution: Joel | Baseline: Eric vs. Injected: Eric
# sample_307 - Solution: Kayla | Baseline: Kayla vs. Injected: Kayla
# sample_308 - Solution: Joseph | Baseline: Joseph vs. Injected: Joseph
# sample_309 - Solution: Hunter | Baseline: Justin vs. Injected: Justin
# sample_310 - Solution: mediation | Baseline: medication vs. Injected: medication
# sample_311 - Solution: Jason | Baseline: Jason vs. Injected: Jason
# sample_312 - Solution: Benjamin | Baseline: Jason vs. Injected: Jason
# sample_313 - Solution: caramel | Baseline: chocolate vs. Injected: caramel
# sample_314 - Solution: chocolate | Baseline: chocolate vs. Injected: chocolate
# sample_315 - Solution: budget | Baseline: budget vs. Injected: budget
# sample_316 - Solution: meeting | Baseline: meeting vs. Injected: meeting
# sample_317 - Solution: sponges | Baseline: sponges vs. Injected: sponges
# sample_318 - Solution: Randy | Baseline: Adam vs. Injected: Adam
# sample_319 - Solution: bedroom | Baseline: bedroom vs. Injected: bedroom
# sample_320 - Solution: bathroom | Baseline: bedroom vs. Injected: bathroom
# sample_321 - Solution: Michael | Baseline: Michael vs. Injected: Kevin
# sample_322 - Solution: Kevin | Baseline: Kevin vs. Injected: Kevin
# sample_323 - Solution: comb | Baseline: hair vs. Injected: comb
# sample_324 - Solution: Maria | Baseline: Cynthia vs. Injected: Maria
# sample_325 - Solution: Cynthia | Baseline: Maria vs. Injected: Cynthia
# sample_326 - Solution: Hunter | Baseline: Dennis vs. Injected: Dennis
# sample_327 - Solution: Robert | Baseline: Robert vs. Injected: Jeffrey
# sample_328 - Solution: Maria | Baseline: Cynthia vs. Injected: Maria
# sample_329 - Solution: Nelson | Baseline: Justin vs. Injected: Nelson
# sample_330 - Solution: Justin | Baseline: Nelson vs. Injected: Justin
# sample_331 - Solution: Angela | Baseline: Angela vs. Injected: Angela
# sample_332 - Solution: Carrie | Baseline: Monica vs. Injected: Carrie
# sample_333 - Solution: Donald | Baseline: Donald vs. Injected: Donald
# sample_334 - Solution: Felicia | Baseline: Felicia vs. Injected: Katrina
# sample_335 - Solution: Katrina | Baseline: Felicia vs. Injected: Felicia
# sample_336 - Solution: Sarah | Baseline: Sarah vs. Injected: Sarah
# sample_337 - Solution: Nelson | Baseline: Neil vs. Injected: Neil
# sample_338 - Solution: Derrick | Baseline: Derrick vs. Injected: William
# sample_339 - Solution: William | Baseline: William vs. Injected: William
# sample_340 - Solution: inn | Baseline: inn vs. Injected: inn
# sample_341 - Solution: hotel | Baseline: hotel vs. Injected: inn
# sample_342 - Solution: interview | Baseline: interview vs. Injected: interview
# sample_343 - Solution: truck | Baseline: car vs. Injected: truck
# sample_344 - Solution: car | Baseline: truck vs. Injected: truck
# sample_345 - Solution: glasses | Baseline: contacts vs. Injected: contacts
# sample_346 - Solution: e-mail | Baseline: letter vs. Injected: letter
# sample_347 - Solution: tea | Baseline: tea vs. Injected: tea
# sample_348 - Solution: Jennifer | Baseline: Jennifer vs. Injected: Jennifer
# sample_349 - Solution: Adam | Baseline: Adam vs. Injected: Adam
# sample_350 - Solution: Cynthia | Baseline: Cynthia vs. Injected: Elena
# sample_351 - Solution: Elena | Baseline: Cynthia vs. Injected: Cynthia
# sample_352 - Solution: Kenneth | Baseline: Kenneth vs. Injected: Kenneth
# sample_353 - Solution: Eric | Baseline: Eric vs. Injected: Kevin
# sample_354 - Solution: Mary | Baseline: Jennifer vs. Injected: Jennifer
# sample_355 - Solution: Ryan | Baseline: Donald vs. Injected: Donald
# sample_356 - Solution: cake | Baseline: cake vs. Injected: cake
# sample_357 - Solution: Hunter | Baseline: Hunter vs. Injected: Hunter
# sample_358 - Solution: Craig | Baseline: Craig vs. Injected: Craig
# sample_359 - Solution: Carrie | Baseline: Laura vs. Injected: Carrie
# sample_360 - Solution: Benjamin | Baseline: Benjamin vs. Injected: Benjamin
# sample_361 - Solution: oil | Baseline: oil vs. Injected: oil
# sample_362 - Solution: water | Baseline: oil vs. Injected: oil
# sample_363 - Solution: frame | Baseline: frame vs. Injected: pole
# sample_364 - Solution: pole | Baseline: frame vs. Injected: pole
# sample_365 - Solution: paper cups | Baseline: styrofoam cups vs. Injected: styrofoam cups
# sample_366 - Solution: Sarah | Baseline: Monica vs. Injected: Sarah
# sample_367 - Solution: Robert | Baseline: Robert vs. Injected: Robert
# sample_368 - Solution: makeup | Baseline: makeup vs. Injected: skin
# sample_369 - Solution: Ian | Baseline: Ian vs. Injected: Ian
# sample_370 - Solution: carrots | Baseline: carrots vs. Injected: carrots
# sample_371 - Solution: door | Baseline: door vs. Injected: door
# sample_372 - Solution: Erin | Baseline: Erin vs. Injected: Erin
# sample_373 - Solution: Logan | Baseline: Robert vs. Injected: Robert
# sample_374 - Solution: Betty | Baseline: Erin vs. Injected: Erin
# sample_375 - Solution: Erin | Baseline: Erin vs. Injected: Betty
# sample_376 - Solution: truck | Baseline: car vs. Injected: car
# sample_377 - Solution: car | Baseline: car vs. Injected: truck
# sample_378 - Solution: Carrie | Baseline: Carrie vs. Injected: Jennifer
# sample_379 - Solution: Ian | Baseline: Ian vs. Injected: Ian
# sample_380 - Solution: Patricia | Baseline: Patricia vs. Injected: Patricia
# sample_381 - Solution: hose | Baseline: hose vs. Injected: hose
# sample_382 - Solution: Amy | Baseline: Amy vs. Injected: Amy
# sample_383 - Solution: washer | Baseline: washer vs. Injected: dryer
# sample_384 - Solution: cake | Baseline: cake vs. Injected: cake
# sample_385 - Solution: hole | Baseline: hole vs. Injected: hole
# sample_386 - Solution: pit | Baseline: pit vs. Injected: pit
# sample_387 - Solution: container | Baseline: container vs. Injected: roller
# sample_388 - Solution: city | Baseline: city vs. Injected: city
# sample_389 - Solution: refrigerator | Baseline: refrigerator vs. Injected: part
# sample_390 - Solution: Patricia | Baseline: Patricia vs. Injected: Patricia
# sample_391 - Solution: Erin | Baseline: Patricia vs. Injected: Erin
# sample_392 - Solution: Kayla | Baseline: Emily vs. Injected: Kayla
# sample_393 - Solution: Tanya | Baseline: Erin vs. Injected: Tanya
# sample_394 - Solution: closets | Baseline: closets vs. Injected: clothes
# sample_395 - Solution: Benjamin | Baseline: Benjamin vs. Injected: Benjamin
# sample_396 - Solution: Neil | Baseline: Jeffrey vs. Injected: Jeffrey
# sample_397 - Solution: gifts | Baseline: dishes vs. Injected: dishes
# sample_398 - Solution: Megan | Baseline: Megan vs. Injected: Megan
# sample_399 - Solution: Craig | Baseline: Craig vs. Injected: Craig
# sample_400 - Solution: Dennis | Baseline: Ian vs. Injected: Dennis
# sample_401 - Solution: clothes | Baseline: clothes vs. Injected: clothes
# sample_402 - Solution: walls | Baseline: walls vs. Injected: clothes
# sample_403 - Solution: Maria | Baseline: Maria vs. Injected: Natalie
# sample_404 - Solution: Natalie | Baseline: Maria vs. Injected: Natalie
# sample_405 - Solution: Adam | Baseline: Hunter vs. Injected: Adam
# sample_406 - Solution: Felicia | Baseline: Jessica vs. Injected: Jessica
# sample_407 - Solution: Felicia | Baseline: Felicia vs. Injected: Felicia
# sample_408 - Solution: water | Baseline: foot vs. Injected: foot
# sample_409 - Solution: Adam | Baseline: Adam vs. Injected: Benjamin
# sample_410 - Solution: Benjamin | Baseline: Adam vs. Injected: Adam
# sample_411 - Solution: Erin | Baseline: Monica vs. Injected: Erin
# sample_412 - Solution: hand | Baseline: hand vs. Injected: hand
# sample_413 - Solution: glove | Baseline: glove vs. Injected: glove
# sample_414 - Solution: steel | Baseline: foundation vs. Injected: foundation
# sample_415 - Solution: water bottles | Baseline: water bottles vs. Injected: water bottles
# sample_416 - Solution: snacks | Baseline: snacks vs. Injected: snacks
# sample_417 - Solution: magazine | Baseline: magazine vs. Injected: magazine
# sample_418 - Solution: Tanya | Baseline: Tanya vs. Injected: Tanya
# sample_419 - Solution: recycling | Baseline: recycling vs. Injected: recycling
# sample_420 - Solution: burn | Baseline: pain vs. Injected: burn
# sample_421 - Solution: restaurant | Baseline: restaurant vs. Injected: restaurant
# sample_422 - Solution: Kyle | Baseline: Eric vs. Injected: Kyle
# sample_423 - Solution: Cynthia | Baseline: Cynthia vs. Injected: Sarah
# sample_424 - Solution: sticker | Baseline: sticker vs. Injected: sticker
# sample_425 - Solution: cream | Baseline: cream vs. Injected: lotion
# sample_426 - Solution: Jeffrey | Baseline: Jeffrey vs. Injected: Jeffrey
# sample_427 - Solution: Kenneth | Baseline: Jeffrey vs. Injected: Jeffrey
# sample_428 - Solution: Michael | Baseline: Adam vs. Injected: Michael
# sample_429 - Solution: pot | Baseline: pot vs. Injected: pot
# sample_430 - Solution: glass | Baseline: pot vs. Injected: pot
# sample_431 - Solution: ball | Baseline: ball vs. Injected: ball
# sample_432 - Solution: plant | Baseline: garden vs. Injected: garden
# sample_433 - Solution: Amy | Baseline: Erin vs. Injected: Amy
# sample_434 - Solution: William | Baseline: William vs. Injected: William
# sample_435 - Solution: Jessica | Baseline: Angela vs. Injected: Jessica
# sample_436 - Solution: Monica | Baseline: Katrina vs. Injected: Monica
# sample_437 - Solution: beaches | Baseline: highlands vs. Injected: beaches
# sample_438 - Solution: Cynthia | Baseline: Cynthia vs. Injected: Cynthia
# sample_439 - Solution: Jessica | Baseline: Jessica vs. Injected: Christine
# sample_440 - Solution: Kevin | Baseline: Joel vs. Injected: Joel
# sample_441 - Solution: Cynthia | Baseline: Cynthia vs. Injected: Monica
# sample_442 - Solution: Monica | Baseline: Cynthia vs. Injected: Cynthia
# sample_443 - Solution: Christine | Baseline: Christine vs. Injected: Christine
# sample_444 - Solution: Hunter | Baseline: Samuel vs. Injected: Hunter
# sample_445 - Solution: air | Baseline: bedroom vs. Injected: air
# sample_446 - Solution: Ian | Baseline: Robert vs. Injected: Robert
# sample_447 - Solution: ball | Baseline: ball vs. Injected: ditch
# sample_448 - Solution: catering | Baseline: catering vs. Injected: catering
# sample_449 - Solution: food wholesale | Baseline: wholesale vs. Injected: catering
# sample_450 - Solution: Monica | Baseline: Monica vs. Injected: Monica
# sample_451 - Solution: cleaner | Baseline: cleaner vs. Injected: cleaner
# sample_452 - Solution: Christopher | Baseline: Christopher vs. Injected: Christopher
# sample_453 - Solution: Watch | Baseline: The answer: Blade. vs. Injected: Blade
# sample_454 - Solution: Lawrence | Baseline: Randy vs. Injected: Randy
# sample_455 - Solution: shoes | Baseline: shoes vs. Injected: shoes
# sample_456 - Solution: chairs | Baseline: chairs vs. Injected: chairs
# sample_457 - Solution: hot | Baseline: iced vs. Injected: iced
# sample_458 - Solution: iced | Baseline: iced vs. Injected: iced
# sample_459 - Solution: Samantha | Baseline: Samantha vs. Injected: Samantha
# sample_460 - Solution: bag | Baseline: pocket vs. Injected: pocket
# sample_461 - Solution: pocket | Baseline: bag vs. Injected: pocket
# sample_462 - Solution: Cynthia | Baseline: Cynthia vs. Injected: Cynthia
# sample_463 - Solution: mansion | Baseline: mansion vs. Injected: house
# sample_464 - Solution: William | Baseline: William vs. Injected: Kevin
# sample_465 - Solution: billboard | Baseline: billboard vs. Injected: billboard
# sample_466 - Solution: sign | Baseline: sign vs. Injected: sign
# sample_467 - Solution: Justin | Baseline: Justin vs. Injected: Justin
# sample_468 - Solution: Elena | Baseline: Elena vs. Injected: Elena
# sample_469 - Solution: Ian | Baseline: Joel vs. Injected: Ian
# sample_470 - Solution: dresser | Baseline: dresser vs. Injected: dresser
# sample_471 - Solution: fan | Baseline: fan vs. Injected: dresser
# sample_472 - Solution: pad | Baseline: pad vs. Injected: ice
# sample_473 - Solution: ice | Baseline: ice vs. Injected: ice
# sample_474 - Solution: Kayla | Baseline: Erin vs. Injected: Kayla
# sample_475 - Solution: Kyle | Baseline: Kyle vs. Injected: Kyle
# sample_476 - Solution: Christopher | Baseline: Christopher vs. Injected: Hunter
# sample_477 - Solution: Carrie | Baseline: Patricia vs. Injected: Patricia
# sample_478 - Solution: house | Baseline: house vs. Injected: house
# sample_479 - Solution: Instrument | Baseline: Instrument vs. Injected: Instrument
# sample_480 - Solution: Kenneth | Baseline: Michael vs. Injected: Kenneth
# sample_481 - Solution: communication | Baseline: communication vs. Injected: communication
# sample_482 - Solution: camera | Baseline: camera vs. Injected: camera
# sample_483 - Solution: tripod | Baseline: camera vs. Injected: camera
# sample_484 - Solution: kitchen | Baseline: kitchen vs. Injected: bedroom
# sample_485 - Solution: bedroom | Baseline: kitchen vs. Injected: kitchen
# sample_486 - Solution: Maria | Baseline: Maria vs. Injected: Samantha
# sample_487 - Solution: Amy | Baseline: Lindsey vs. Injected: Lindsey
# sample_488 - Solution: party | Baseline: party vs. Injected: party
# sample_489 - Solution: Betty | Baseline: Betty vs. Injected: Betty
# sample_490 - Solution: Cynthia | Baseline: Betty vs. Injected: Betty
# sample_491 - Solution: remote control | Baseline: remote control vs. Injected: remote control
# sample_492 - Solution: Natalie | Baseline: Natalie vs. Injected: Natalie
# sample_493 - Solution: Joel | Baseline: Robert vs. Injected: Joel
# sample_494 - Solution: Aaron | Baseline: Aaron vs. Injected: Aaron
# sample_495 - Solution: Christopher | Baseline: Christopher vs. Injected: Christopher
# sample_496 - Solution: Carrie | Baseline: Carrie vs. Injected: Carrie
# sample_497 - Solution: Samantha | Baseline: Samantha vs. Injected: Carrie
# sample_498 - Solution: Patricia | Baseline: Patricia vs. Injected: Patricia
# sample_499 - Solution: Cynthia | Baseline: Cynthia vs. Injected: Carrie
#
# ✅ Experiment successfully saved in qwen_experiment_log_20260501_084300.json!

# %% [markdown]
# ## Results

# %%
import json
import matplotlib.pyplot as plt
import textwrap

# 1. Safely split the log into metadata and results
metadata = experiment_log.get("metadata", {})
results = experiment_log.get("results", {})

total_samples = len(results)
baseline_correct = 0
injected_correct = 0

for sample_id, data in results.items():
    # Convert to lowercase and strip whitespace for fair comparison
    solution = str(data["solution"]).strip().lower()
    baseline = str(data["llm_baseline"]).strip().lower()
    injected = str(data["llm_preprocessedReasoning"]).strip().lower()
    
    # Check: Is the correct word contained in the model's answer?
    if solution in baseline:
        baseline_correct += 1
    if solution in injected:
        injected_correct += 1

# Calculate percentage accuracy
baseline_accuracy = (baseline_correct / total_samples) * 100 if total_samples > 0 else 0
injected_accuracy = (injected_correct / total_samples) * 100 if total_samples > 0 else 0

# 📊 The Big Reveal (Console Output)
print("📊 WinoGrande Experiment Results:")
print("=" * 40)
print(f"Total Samples analyzed: {total_samples}")
print("-" * 40)
print(f"🔴 Baseline Accuracy: {baseline_accuracy:.1f}% ({baseline_correct}/{total_samples})")
print(f"🟢 Injected Accuracy: {injected_accuracy:.1f}% ({injected_correct}/{total_samples})")
print("=" * 40)

# Hypothesis Conclusion Generator
if injected_accuracy > baseline_accuracy:
    print("\n🎉 Hypothesis validated: The Precomputed Context (Reasoning Transfer) measurably improved the model!")
elif injected_accuracy == baseline_accuracy:
    print("\n⚖️ Tie: In this sample set, the injection had no statistical effect.")
else:
    print("\n⚠️ Interesting: The baseline was stronger. The injected, foreign thought process confused the model here.")

# 📈 Generate and Save the Plot
labels = ['Baseline', 'Injected Reasoning']
accuracies = [baseline_accuracy, injected_accuracy]
colors = ['#ff6666', '#66cc66'] # Red and Green styling

plt.figure(figsize=(8, 6))
bars = plt.bar(labels, accuracies, color=colors, width=0.5)

# 💡 Extract Metadata for the Plot
dataset_name = metadata.get("dataset", "Unknown")
anchor_index = metadata.get("anchor_sample_index", "Unknown")

plt.ylabel('Accuracy (%)')

# Add a multi-line title containing the experiment parameters
plt.title(f'Experiment 1: Baseline vs. Precomputed Context\n'
          f'Dataset: {dataset_name} | Anchor Index: {anchor_index} | Total Samples: {total_samples}', 
          fontsize=12, pad=15)

plt.ylim(0, 100) # Keep Y-axis fixed from 0 to 100 for proper scientific scale

# Add text annotations directly on top of the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, f'{yval:.1f}%', ha='center', va='bottom', fontweight='bold')

# 💡 Display the full Structure of the Injection Prompt over multiple lines
prompt_structure = metadata.get("injected_prompt_structure", "Structure not found.")

# Wrap the text paragraph by paragraph to preserve existing intentional newlines
wrapped_lines = []
for line in prompt_structure.split('\n'):
    # Wrap each line to ~85 characters so it fits nicely under the graph
    wrapped_lines.append(textwrap.fill(line, width=85) if line else "")
prompt_structure_display = '\n'.join(wrapped_lines)

# Place the text box. va="top" ensures the box expands downwards dynamically
plt.figtext(0.5, -0.05, f"Injection Structure:\n\n{prompt_structure_display}", 
            ha="center", va="top", fontsize=9, linespacing=1.4,
            bbox={"facecolor":"#f0f0f0", "alpha":0.5, "pad":8, "edgecolor":"#cccccc"})

# Save the plot using the timestamp from the previous cell
# bbox_inches='tight' will automatically resize the image canvas to include the new tall text box
plot_filename = f"plots/qwen_experiment_plot_{timestamp}.png"
plt.savefig(plot_filename, bbox_inches='tight', dpi=300) 
print(f"\n📸 Plot successfully saved as: {plot_filename}")

# Display the plot directly in the Jupyter Notebook cell
plt.show()
# Out:
# 📊 WinoGrande Experiment Results:
# ========================================
# Total Samples analyzed: 500
# ----------------------------------------
# 🔴 Baseline Accuracy: 60.4% (302/500)
# 🟢 Injected Accuracy: 61.6% (308/500)
# ========================================
#
# 🎉 Hypothesis validated: The Precomputed Context (Reasoning Transfer) measurably improved the model!
#
# 📸 Plot successfully saved as: qwen_experiment_plot_20260501_084300.png
